# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn import datasets

# %%
#Import data about result
data = pd.read_csv('https://raw.githubusercontent.com/XaviJunior/omega/Data/Data/results.csv')
result=data[["resultId","raceId","driverId", "constructorId","time"]]
#Import data about drivers
datap= pd.read_csv("https://raw.githubusercontent.com/XaviJunior/omega/Data/Data/drivers.csv",encoding = "ISO-8859-1")
drivers=datap[["driverId","driverRef","code"]]
#Import data about cicruits
cir=pd.read_csv('https://raw.githubusercontent.com/XaviJunior/omega/Data/Data/races.csv')
circuit=cir[["raceId","year","name"]]
#Import data about weather
weath=pd.read_csv("https://raw.githubusercontent.com/XaviJunior/omega/Data/Data/Weather_SafetyCar.csv",encoding='utf-8')
weather=weath[["year","name","weather"]]
#Merge circuits and weather
cw=pd.merge(circuit,weather,right_on=["year","name"], left_on=["year","name"])
cw1=cw.rename(columns={"name":"circuit"})
#Merge results and drivers
resultdrivers = pd.merge(result,drivers,left_on='driverId', right_on="driverId")
#Merge weather and result+drivers
resultdriverweather=pd.merge(resultanddrivers,cw1, left_on='raceId', right_on="raceId")

final=resultdriverweather[["driverRef","circuit","weather","year","time"]]
final.head(10)
# Out:
#     driverRef                circuit weather  year     time
# 0    hamilton  Australian Grand Prix     Dry  2008  34:50.6
# 1    heidfeld  Australian Grand Prix     Dry  2008    5.478
# 2     rosberg  Australian Grand Prix     Dry  2008    8.163
# 3      alonso  Australian Grand Prix     Dry  2008   17.181
# 4  kovalainen  Australian Grand Prix     Dry  2008   18.014
# 5    nakajima  Australian Grand Prix     Dry  2008      NaN
# 6    bourdais  Australian Grand Prix     Dry  2008      NaN
# 7   raikkonen  Australian Grand Prix     Dry  2008      NaN
# 8      kubica  Australian Grand Prix     Dry  2008      NaN
# 9       glock  Australian Grand Prix     Dry  2008      NaN
